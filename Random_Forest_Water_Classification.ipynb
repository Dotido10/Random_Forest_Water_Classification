# %% [markdown]
# # *1.Introduction*
# For this work, we will use data from the Sentinel-2 instrument and a Random Forest algorithm to perform water classification.
#
# The intent of this notebook is two-fold:
#
# First, we will perform some training using the Random Forest algorithm.
#
# Second, we will perform inference using the Random Forest algorithm, and will include some metrics to analyze its performance.
#
# For this exercise we have downloaded our features data from the copernicus platform by using the Google Earth Engine .
#
# We digitized manually our labeled data from the sentinel-2 image by using the QGIS software. Water extend frorm Lakes Azeui and Enriquillo in the island of Haiti were used.
#
# **Author : Renaldo Sauveur**
#
# **Last Modified : 08/04/2024**

# %% [markdown]
# # *2.Import Libraries*
# In this section we import the Python libraries to use during the development of this notebook.

# %%
# Import module
import numpy as np
import pandas as pd
import joblib
from joblib import dump
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import rasterio as rio
from rasterio.plot import show 
import os
import datetime
import optuna
import seaborn as sns

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, precision_score, f1_score
from sklearn.metrics import classification_report, roc_curve, auc
from sklearn.inspection import permutation_importance

import sys
sys.path.append('/kaggle/input/localfolium/')

import folium
from folium import plugins
import folium_helper

# %%
# controls random seed for reproducibility
RANDOM_STATE = 42

# %% [markdown]
# # *3.Data Loading and Exploratory Data Analysis*
# In this section we have extracted a tabular dataset from Sentinel tiff files for the purpose of performing Exploratory Data Analysis (EDA).

# %%
# Datasets
os.listdir('/kaggle/input/')
# Out:
# ['haitilandwatermask', 'localfolium']

# %%
# Dataset raster image X_train
ds = rio.open('/kaggle/input/haitilandwatermask/X_train.tif') 
arr = ds.read()
arr = np.moveaxis(arr, 0, -1)
arr = np.where(np.isnan(arr), 0, arr)

nrow_train = arr.shape[0]
ncol_train = arr.shape[1]

X_train = np.reshape(arr, (arr.shape[0] * arr.shape[1], arr.shape[2]))
X_train.shape
# Out:
# (32947515, 4)

# %%
ds.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': None,
#  'width': 8751,
#  'height': 3765,
#  'count': 4,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(8.983152841195215e-05, 0.0, -72.19885702608372,
#         0.0, -8.983152841195215e-05, 18.692773252657886)}

# %%
show(ds)
# Out:
# <Axes: >

# %%
# open raster image X_test
ds = rio.open('/kaggle/input/haitilandwatermask/X_test.tif')
arr = ds.read()
arr = np.moveaxis(arr, 0, -1)
arr = np.where(np.isnan(arr), 0, arr)

nrow_test = arr[0]
ncol_test = arr[1]

X_test = np.reshape(arr, (arr.shape[0] * arr.shape[1], arr.shape[2]))
X_test.shape
# Out:
# (4214412, 4)

# %%
ds.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': None,
#  'width': 2004,
#  'height': 2103,
#  'count': 4,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(8.983152841195215e-05, 0.0, -70.32281538672851,
#         0.0, -8.983152841195215e-05, 19.08363023277829)}

# %%
show(ds)
# Out:
# <Axes: >

# %%
# open raster image y_train
ds = rio.open('/kaggle/input/haitilandwatermask/y_train.tif')
arr=ds.read()
arr = np.moveaxis(arr, 0, -1)
arr = np.where(arr == np.nan, 0, arr)
y_train = arr.reshape(-1)
y_train.shape
# Out:
# (32947515,)

# %%
ds.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 8751,
#  'height': 3765,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(8.983152841195215e-05, 0.0, -72.19885702608372,
#         0.0, -8.983152841195215e-05, 18.692773252657886)}

# %%
show(ds)
# Out:
# <Axes: >

# %%
# open raster image y_test
ds = rio.open('/kaggle/input/haitilandwatermask/y_test.tif')
arr = ds.read()
arr = np.moveaxis(arr, 0, -1)
arr = np.where(np.isnan(arr), 0, arr)
y_test = arr.reshape(-1)
y_test.shape
# Out:
# (4214412,)

# %%
ds.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 2004,
#  'height': 2103,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(8.983152841195215e-05, 0.0, -70.32281538672851,
#         0.0, -8.983152841195215e-05, 19.08363023277829)}

# %%
show(ds)
# Out:
# <Axes: >

# %%
X_train
# Out:
# array([[0.1039    , 0.0976    , 0.0842    , 0.2294    ],
#        [0.1077    , 0.1012    , 0.0878    , 0.2441    ],
#        [0.1091    , 0.1036    , 0.0878    , 0.2414    ],
#        ...,
#        [0.12244   , 0.12248334, 0.11885   , 0.2394    ],
#        [0.1207    , 0.12163334, 0.1167    , 0.2515    ],
#        [0.12353333, 0.1212    , 0.1214    , 0.2409    ]], dtype=float32)

# %%
X_train.shape
# Out:
# (32947515, 4)

# %% [markdown]
# If we want to know if our data contains any no-data values

# %%
np.count_nonzero(np.isnan(X_train))
# Out:
# 0

# %%
np.where(X_train == 0)
# Out:
# (array([       7,        7,        7, ..., 32947508, 32947508, 32947508]),
#  array([0, 1, 2, ..., 1, 2, 3]))

# %%
df_X_train = pd.DataFrame(X_train, columns=['B2', 'B3', 'B4', 'B8'])

# %%
df_X_train
# Out:
#                 B2        B3       B4        B8
# 0         0.103900  0.097600  0.08420  0.229400
# 1         0.107700  0.101200  0.08780  0.244100
# 2         0.109100  0.103600  0.08780  0.241400
# 3         0.103050  0.097800  0.08210  0.247900
# 4         0.106350  0.101400  0.08575  0.250650
# ...            ...       ...      ...       ...
# 32947510  0.123700  0.123650  0.12670  0.244475
# 32947511  0.121620  0.119750  0.12240  0.233650
# 32947512  0.122440  0.122483  0.11885  0.239400
# 32947513  0.120700  0.121633  0.11670  0.251500
# 32947514  0.123533  0.121200  0.12140  0.240900
#
# [32947515 rows x 4 columns]

# %% [markdown]
# Here we can then observe some statistics from the dataset

# %%
df_X_train.describe().T
# Out:
#          count      mean       std  min  25%       50%       75%     max
# B2  32947515.0  0.078052  0.057806  0.0  0.0  0.089600  0.114800  0.5304
# B3  32947515.0  0.074699  0.058789  0.0  0.0  0.081400  0.111633  0.5955
# B4  32947515.0  0.066422  0.063203  0.0  0.0  0.055267  0.104500  0.7412
# B8  32947515.0  0.144872  0.128411  0.0  0.0  0.195900  0.257700  0.8464

# %%
df_X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32947515 entries, 0 to 32947514
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   B2      float32
#  1   B3      float32
#  2   B4      float32
#  3   B8      float32
# dtypes: float32(4)
# memory usage: 502.7 MB

# %%
df_X_train[df_X_train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [B2, B3, B4, B8]
# Index: []

# %%
df_train = df_X_train.copy()

# %%
df_train = df_X_train.assign(y=y_train.tolist())

# %%
df_train
# Out:
#                 B2        B3       B4        B8  y
# 0         0.103900  0.097600  0.08420  0.229400  0
# 1         0.107700  0.101200  0.08780  0.244100  0
# 2         0.109100  0.103600  0.08780  0.241400  0
# 3         0.103050  0.097800  0.08210  0.247900  0
# 4         0.106350  0.101400  0.08575  0.250650  0
# ...            ...       ...      ...       ... ..
# 32947510  0.123700  0.123650  0.12670  0.244475  0
# 32947511  0.121620  0.119750  0.12240  0.233650  0
# 32947512  0.122440  0.122483  0.11885  0.239400  0
# 32947513  0.120700  0.121633  0.11670  0.251500  0
# 32947514  0.123533  0.121200  0.12140  0.240900  0
#
# [32947515 rows x 5 columns]

# %% [markdown]
# Distribution for each channel.
#
# This section show where most of your data lives for each feature in the dataset, including the distribution of training labels.

# %%
df_train.hist(figsize=(16, 20), bins=50)
# Out:
# array([[<Axes: title={'center': 'B2'}>, <Axes: title={'center': 'B3'}>],
#        [<Axes: title={'center': 'B4'}>, <Axes: title={'center': 'B8'}>],
#        [<Axes: title={'center': 'y'}>, <Axes: >]], dtype=object)

# %%
df_y_train = pd.DataFrame(y_train, columns=['value'])

# %%
df_y_train["value"].unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
df_y_test = pd.DataFrame(y_test, columns=['value'])

# %%
df_y_test["value"].unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
df_y_train.value_counts(), df_y_test.value_counts()
# Out:
# (value
#  0        28585005
#  1         4362510
#  Name: count, dtype: int64,
#  value
#  0        3960859
#  1         253553
#  Name: count, dtype: int64)

# %% [markdown]
# The distribution of the training features is 87% for not-water and 13% for water.
#
# The distribution of the testing features is 94% for not-water and 6% for water.
#
# Our datasets are imbalanced datasets, which means we need more water data for a better solution.

# %% [markdown]
# Correlation plots
#
# The correlation step can help us find interesting features in our data by looking directly into relationships between our feature columns and our labels.

# %%
# full correlation table
df_X_train.corr().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_7fcd9_row0_col0, #T_7fcd9_row1_col1, #T_7fcd9_row2_col2, #T_7fcd9_row3_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7fcd9_row0_col1 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_7fcd9_row0_col2 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_7fcd9_row0_col3 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_7fcd9_row1_col0 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_7fcd9_row1_col2 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_7fcd9_row1_col3 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_7fcd9_row2_col0 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_7fcd9_row2_col1 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_7fcd9_row2_col3, #T_7fcd9_row3_col0, #T_7fcd9_row3_col1, #T_7fcd9_row3_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7fcd9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fcd9_level0_col0" class="col_heading level0 col0" >B2</th>
#       <th id="T_7fcd9_level0_col1" class="col_heading level0 col1" >B3</th>
#       <th id="T_7fcd9_level0_col2" class="col_heading level0 col2" >B4</th>
#       <th id="T_7fcd9_level0_col3" class="col_heading level0 col3" >B8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fcd9_level0_row0" class="row_heading level0 row0" >B2</th>
#       <td id="T_7fcd9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7fcd9_row0_col1" class="data row0 col1" >0.991452</td>
#       <td id="T_7fcd9_row0_col2" class="data row0 col2" >0.936678</td>
#       <td id="T_7fcd9_row0_col3" class="data row0 col3" >0.818421</td>
#     </tr>
#     <tr>
#       <th id="T_7fcd9_level0_row1" class="row_heading level0 row1" >B3</th>
#       <td id="T_7fcd9_row1_col0" class="data row1 col0" >0.991452</td>
#       <td id="T_7fcd9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7fcd9_row1_col2" class="data row1 col2" >0.967859</td>
#       <td id="T_7fcd9_row1_col3" class="data row1 col3" >0.836755</td>
#     </tr>
#     <tr>
#       <th id="T_7fcd9_level0_row2" class="row_heading level0 row2" >B4</th>
#       <td id="T_7fcd9_row2_col0" class="data row2 col0" >0.936678</td>
#       <td id="T_7fcd9_row2_col1" class="data row2 col1" >0.967859</td>
#       <td id="T_7fcd9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7fcd9_row2_col3" class="data row2 col3" >0.807183</td>
#     </tr>
#     <tr>
#       <th id="T_7fcd9_level0_row3" class="row_heading level0 row3" >B8</th>
#       <td id="T_7fcd9_row3_col0" class="data row3 col0" >0.818421</td>
#       <td id="T_7fcd9_row3_col1" class="data row3 col1" >0.836755</td>
#       <td id="T_7fcd9_row3_col2" class="data row3 col2" >0.807183</td>
#       <td id="T_7fcd9_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# correlation with dataset - target value
corr = df_train.corr()['y']
corr
# Out:
# B2    0.067592
# B3   -0.006564
# B4   -0.154384
# B8   -0.376064
# y     1.000000
# Name: y, dtype: float64

# %%
nrow_test = arr.shape[0]
ncol_test = arr.shape[1]

# %% [markdown]
# # *4.Model definition and training*
# We define our classifier, and perform the fit operation directly on the training dataset.

# %%
hyperparameters = {'n_estimators': 100, 
                   'criterion':'gini', 
                   'max_depth':None, 
                   'min_samples_split':2, 
                   'min_samples_leaf':1, 
                   'min_weight_fraction_leaf':0.0, 
                   'max_features':'sqrt', 
                   'max_leaf_nodes':None, 
                   'min_impurity_decrease':0.0, 
                   'bootstrap':True, 
                   'oob_score':False, 
                   'n_jobs':-1, 
                   'random_state':42, 
                   'verbose':3, 
                   'warm_start':False, 
                   'class_weight':None, 
                   'ccp_alpha':0.0, 
                   'max_samples':None
                  }

# %%
rfc = RandomForestClassifier(**hyperparameters)

# %%
# Fit model
rfc.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 14.5min
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 59.8min finished
# RandomForestClassifier(n_jobs=-1, random_state=42, verbose=3)

# %%
# Make predictions
y_pred = rfc.predict(X_test)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.6s finished

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
y_pred_reshaped = y_pred.reshape(nrow_test, ncol_test)
y_test_reshaped = y_test.reshape(nrow_test, ncol_test)
X_test_reshaped = X_test.reshape(nrow_test, ncol_test, 4)
print(y_pred_reshaped.shape, X_test_reshaped.shape)
# Out:
# (2103, 2004) (2103, 2004, 4)

# %% [markdown]
# # 5. *Visualization of the output*

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(12,8))
ax1, ax2, ax3, ax4 = axes.flatten()

ax1.set_title("RGB", fontweight='bold', fontsize='16')
ax1.imshow(X_test_reshaped[:,:,:3])

ax2.set_title("NRI", fontweight='bold', fontsize='16')
ax2.imshow(X_test_reshaped[:,:,3])

ax3.set_title("Ground Truth", fontweight='bold', fontsize='16')
ax3.imshow(y_test_reshaped[:,:])

ax4.set_title("Predicted", fontweight='bold', fontsize='16')
ax4.imshow(y_pred_reshaped[:,:])

plt.tight_layout()

plt.show()

# %%
#Visualising raster from array
rio.plot.show(y_pred_reshaped);

# %%
y_pred_reshaped.dtype
# Out:
# dtype('uint8')

# %%
# Output the predicted to GeoTiff
raster = rio.open('/kaggle/input/haitilandwatermask/X_test.tif')

with    rio.open(
        "./predicted.tif", "w",
        driver = "GTiff",
        crs = raster.crs,
        transform = raster.transform,
        dtype = rio.uint8,
        count = raster.count,
        width = raster.width,
        height = raster.height) as dst:
    dst.write(y_pred_reshaped, indexes = 1)

# %%
predictedPath = os.getcwd() + "/predicted.tif"

# %% [markdown]
# We can then proceed to visualize the output of our model in an interactive map.
#
# But first, we need to fix the projection in order to properly display the map using the interactive visualization package called folium.

# %%
mask_3857 = folium_helper.reproject_to_3857(predictedPath)
mask_d = folium_helper.get_bounds(mask_3857)
mask_b1 = folium_helper.open_and_get_band(mask_3857, 1)
folium_helper.cleanup(mask_3857)
mask_b1 = np.where(mask_b1 == 255, 0, mask_b1)
zeros = np.zeros_like(mask_b1)
mask_rgb = np.dstack((mask_b1, zeros, zeros))
# Out:
# Transform: | 10.31, 0.00,-7828300.00|
# | 0.00,-10.31, 2164784.50|
# | 0.00, 0.00, 1.00|
# Width: 1945 Height: 2158

# %%
m = folium.Map(location=[mask_d['center'][1], mask_d['center'][0]],
                   tiles='https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}', zoom_start = 6, attr='Google')

# %%
m.add_child(folium_helper.get_overlay(mask_rgb, mask_d, 'Water classification RF predicted mask', opacity=0.6))
m.add_child(plugins.MousePosition())
m.add_child(folium.LayerControl())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60a745c545bb57cea87af28b3b58451f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60a745c545bb57cea87af28b3b58451f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60a745c545bb57cea87af28b3b58451f = L.map(
#                 &quot;map_60a745c545bb57cea87af28b3b58451f&quot;,
#                 {
#                     center: [18.989175631852355, -70.23278414953117],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_195b6afb099eba0b0a8bd6e0ce4f37cf = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_195b6afb099eba0b0a8bd6e0ce4f37cf.addTo(map_60a745c545bb57cea87af28b3b58451f);
#
#
#             var image_overlay_c23e23c9291eb07b2cfbc012b6e439f6 = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[18.894721030926423, -70.32281538672851], [19.083630232778287, -70.14275291233385]],
#                 {&quot;opacity&quot;: 0.6}
#             );
#
#
#             image_overlay_c23e23c9291eb07b2cfbc012b6e439f6.addTo(map_60a745c545bb57cea87af28b3b58451f);
#
#
#             var mouse_position_5ce59ad1d44f45580aeba05dd0408c21 = new L.Control.MousePosition(
#                 {&quot;emptyString&quot;: &quot;Unavailable&quot;, &quot;lngFirst&quot;: false, &quot;numDigits&quot;: 5, &quot;position&quot;: &quot;bottomright&quot;, &quot;prefix&quot;: &quot;&quot;, &quot;separator&quot;: &quot; : &quot;}
#             );
#             mouse_position_5ce59ad1d44f45580aeba05dd0408c21.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_5ce59ad1d44f45580aeba05dd0408c21.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_60a745c545bb57cea87af28b3b58451f.addControl(mouse_position_5ce59ad1d44f45580aeba05dd0408c21);
#
#
#             var layer_control_41c37ebbda44bcbdd0f7b645752b6c9a_layers = {
#                 base_layers : {
#                     &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot; : tile_layer_195b6afb099eba0b0a8bd6e0ce4f37cf,
#                 },
#                 overlays :  {
#                     &quot;Water classification RF predicted mask&quot; : image_overlay_c23e23c9291eb07b2cfbc012b6e439f6,
#                 },
#             };
#             let layer_control_41c37ebbda44bcbdd0f7b645752b6c9a = L.control.layers(
#                 layer_control_41c37ebbda44bcbdd0f7b645752b6c9a_layers.base_layers,
#                 layer_control_41c37ebbda44bcbdd0f7b645752b6c9a_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_60a745c545bb57cea87af28b3b58451f);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
#  # *6.Get model metrics*

# %%
# Score computation from the model output
score = rfc.score(X_test, y_test)
score = round(score, 3)
score
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.9s finished
# 0.987

# %%
train_predictions = rfc.predict(X_train)
test_predictions = rfc.predict(X_test)
prediction_probs = rfc.predict_proba(X_test)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:  1.9min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.3s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished

# %%
predictionProbabilityList = list()
for i, subarr in enumerate(prediction_probs):
    predictionProbabilityList.append(subarr[1])
predictionProbabilityArray = np.asarray(predictionProbabilityList)

# %% [markdown]
# These are the probability that each test data point is water p=1 vs land p=0.

# %%
sns.displot(predictionProbabilityArray, bins=30)
plt.title('Distribution of the probability of predicted values')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of the probability of predicted values')

# %%
test_predictions = test_predictions.astype(np.int32)
y_test_int = y_test.astype(np.int32)

# %% [markdown]
# We can compute additional metrics to understand model performance related to producer and user accuracy.

# %%
print('Test Performance')
print('-------------------------------------------------------')
print(classification_report(y_test, test_predictions))
cm = confusion_matrix(y_test_int, test_predictions)
recall = (cm[0][0] / (cm[0][0] + cm[0][1]))
print('Test Recall')
print('-------------------------------------------------------')
print(recall)
print('Confusion Matrix')
print('-------------------------------------------------------')
print(cm)
# Out:
# Test Performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99   3960859
#            1       0.96      0.81      0.88    253553
#
#     accuracy                           0.99   4214412
#    macro avg       0.98      0.90      0.94   4214412
# weighted avg       0.99      0.99      0.99   4214412
#
# Test Recall
# -------------------------------------------------------
# 0.9980827391230034
# Confusion Matrix
# -------------------------------------------------------
# [[3953265    7594]
#  [  47722  205831]]

# %% [markdown]
# We can also look at Receiver Operating Characteristic (ROC) plots to understand the performance of the model across all samples between True Positive and False Positive rates.

# %%
clf = rfc

probs = clf.predict_proba(X_test)
preds = probs[:, 1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'red', label = 'ROC AUC score = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'b--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.9s finished

# %% [markdown]
# Another important metric to understand model performance is to evaluate permutation importance, particularly focused on the importance of each feature in the training and inference of the model.

# %%
# %%time
permutation_importance_results = permutation_importance(rfc,
                                                        X=X_test,
                                                        y=y_test,
                                                        n_repeats=10,
                                                        random_state=42)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.4s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.5s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.5s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.4s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.8s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.3s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.8s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.9s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.3s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.8s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.8s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.8s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.4s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   18.3s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   15.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.6s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.5s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.5s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   13.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   13.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.5s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   13.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   12.5s finished
# CPU times: user 27min 24s, sys: 3min 56s, total: 31min 21s
# Wall time: 8min 36s

# %%
sorted_idx = permutation_importance_results.importances_mean.argsort()
plt.figure(figsize=(8, 8))
plt.barh(df_X_train.columns[sorted_idx], permutation_importance_results.importances_mean[sorted_idx])
plt.xlabel("Permutation Importance")
# Out:
# Text(0.5, 0, 'Permutation Importance')

# %% [markdown]
# Note how the B1 band was the variable of most importance during the training and inference of the model.

# %% [markdown]
# **References :**
#
# https://appliedsciences.nasa.gov/get-involved/training/english/arset-fundamentals-machine-learning-earth-science
#
# https://www.youtube.com/watch?v=CXlGhiJWKGg&t=210s
